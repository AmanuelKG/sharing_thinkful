# %% [markdown]
# ### Challenge: sentiment analysis with Naive bayes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# %matplotlib inline

# %% [markdown]
# Firtst lets load the data that we want work with.

# %%
amazon_data = pd.read_csv('amazon_cells_labelled.txt',delimiter= '\t', header= None)
amazon_data.columns = ['Reviews', 'Positive_negative']

# %%
pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)
amazon_data.head(50)
# Out:
#                                                                                                                 Reviews  Positive_negative
# 0   So there is no way for me to plug it in here in the US unless I go by a converter.                                   0
# 1   Good case, Excellent value.                                                                                          1
# 2   Great for the jawbone.                                                                                               1
# 3   Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!                                      0
# 4   The mic is great.                                                                                                    1
# 5   I have to jiggle the plug to get it to line up right to get decent volume.                                           0
# 6   If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one.      0
# 7   If you are Razr owner...you must have this!                                                                          1
# 8   Needless to say, I wasted my money.                                                                                  0
# 9   What a waste of money and time!.                                                                                     0
# 10  And the sound quality is great.                                                                                      1
# 11  He was very impressed when going from the original battery to the extended battery.                                  1
# 12  If the two were seperated by a mere 5+ ft I started to notice excessive static and garbled sound from the headset.   0
# 13  Very good quality though                                                                                             1
# 14  The design is very odd, as the ear "clip" is not very comfortable at all.                                            0
# 15  Highly recommend for any one who has a blue tooth phone.                                                             1
# 16  I advise EVERYONE DO NOT BE FOOLED!                                                                                  0
# 17  So Far So Good!.                                                                                                     1
# 18  Works great!.                                                                                                        1
# 19  It clicks into place in a way that makes you wonder how long that mechanism would last.                              0
# 20  I went on Motorola's website and followed all directions, but could not get it to pair again.                        0
# 21  I bought this to use with my Kindle Fire and absolutely loved it!                                                    1
# 22  The commercials are the most misleading.                                                                             0
# 23  I have yet to run this new battery below two bars and that's three days without charging.                            1
# 24  I bought it for my mother and she had a problem with the battery.                                                    0
# 25  Great Pocket PC / phone combination.                                                                                 1
# 26  I've owned this phone for 7 months now and can say that it's the best mobile phone I've had.                         1
# 27  I didn't think that the instructions provided were helpful to me.                                                    0
# 28  People couldnt hear me talk and I had to pull out the earphone and talk on the phone.                                0
# 29  Doesn't hold charge.                                                                                                 0
# 30  This is a simple little phone to use, but the breakage is unacceptible.                                              0
# 31  This product is ideal for people like me whose ears are very sensitive.                                              1
# 32  It is unusable in a moving car at freeway speed.                                                                     0
# 33  I have two more years left in this contract and I hate this phone.                                                   0
# 34  Car charger as well as AC charger are included to make sure you never run out of juice.Highy recommended             1
# 35  You need at least 3 mins to get to your phone book from the time you first turn on the phone.Battery life is short.  0
# 36  It has kept up very well.                                                                                            1
# 37  Poor Talk Time Performance.                                                                                          0
# 38  The case is great and works fine with the 680.                                                                       1
# 39  worthless product.                                                                                                   0
# 40  It has a great camera thats 2MP, and the pics are nice and clear with great picture quality.                         1
# 41  I was not impressed by this product.                                                                                 0
# 42  Nice headset priced right.                                                                                           1
# 43  I only hear garbage for audio.                                                                                       0
# 44  Excellent bluetooth headset.                                                                                         1
# 45  It has all the features I want                                                                                       1
# 46  Who in their right mind is gonna buy this battery?.                                                                  0
# 47  AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS.                        0
# 48  This case seems well made.                                                                                           1
# 49  Disappointed with battery.                                                                                           0

# %% [markdown]
# Lets explore our data

# %%
amazon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
# Reviews              1000 non-null object
# Positive_negative    1000 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 15.7+ KB

# %% [markdown]
# we dont have any missing value

# %% [markdown]
# Now lets see the proportions of positive and negative reviews in our data

# %%
amazon_data['Positive_negative'].value_counts()/1000
# Out:
# 1    0.5
# 0    0.5
# Name: Positive_negative, dtype: float64

# %% [markdown]
# we can see from the above result that there are equal numbers of postive and negative reviews

# %% [markdown]
# Lets move on and create features for our data for developing our model of identifying a positive and a negative reviews.

# %% [markdown]
# lets begin by creating the possible keywords for positive reviews;

# %%
keywords = ['excellent','good', 'great', 'impressive', 'amazing', 'loved' 
            , 'recommended', 'nice', 'best', 'beautiful', 'happy']

# %% [markdown]
# by observing and going through the messages in our data, i learned that the keywords that i have listed in the above are written in a different capitalization.some are capitalized and some are not.keeping that in mind lets create our feature variables for creating our new modelling data.Since our original data is labelled our target variable is known and it is the 'positive_negative' variable in the amazon_data dataset.

# %%
import re
for key in keywords:
    amazon_data[key] = amazon_data.Reviews.apply(lambda x: bool(re.search(r'{}'.format(key), x, re.IGNORECASE)))

# %%
amazon_data.head(50)
# Out:
#                                                                                                                 Reviews  Positive_negative  excellent   good  great  impressive  amazing  loved  recommended   nice   best  beautiful  happy
# 0   So there is no way for me to plug it in here in the US unless I go by a converter.                                   0                  False      False  False  False       False    False  False        False  False  False      False
# 1   Good case, Excellent value.                                                                                          1                  True       True   False  False       False    False  False        False  False  False      False
# 2   Great for the jawbone.                                                                                               1                  False      False  True   False       False    False  False        False  False  False      False
# 3   Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!                                      0                  False      False  False  False       False    False  False        False  False  False      False
# 4   The mic is great.                                                                                                    1                  False      False  True   False       False    False  False        False  False  False      False
# 5   I have to jiggle the plug to get it to line up right to get decent volume.                                           0                  False      False  False  False       False    False  False        False  False  False      False
# 6   If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one.      0                  False      False  False  False       False    False  False        False  False  False      False
# 7   If you are Razr owner...you must have this!                                                                          1                  False      False  False  False       False    False  False        False  False  False      False
# 8   Needless to say, I wasted my money.                                                                                  0                  False      False  False  False       False    False  False        False  False  False      False
# 9   What a waste of money and time!.                                                                                     0                  False      False  False  False       False    False  False        False  False  False      False
# 10  And the sound quality is great.                                                                                      1                  False      False  True   False       False    False  False        False  False  False      False
# 11  He was very impressed when going from the original battery to the extended battery.                                  1                  False      False  False  False       False    False  False        False  False  False      False
# 12  If the two were seperated by a mere 5+ ft I started to notice excessive static and garbled sound from the headset.   0                  False      False  False  False       False    False  False        False  False  False      False
# 13  Very good quality though                                                                                             1                  False      True   False  False       False    False  False        False  False  False      False
# 14  The design is very odd, as the ear "clip" is not very comfortable at all.                                            0                  False      False  False  False       False    False  False        False  False  False      False
# 15  Highly recommend for any one who has a blue tooth phone.                                                             1                  False      False  False  False       False    False  False        False  False  False      False
# 16  I advise EVERYONE DO NOT BE FOOLED!                                                                                  0                  False      False  False  False       False    False  False        False  False  False      False
# 17  So Far So Good!.                                                                                                     1                  False      True   False  False       False    False  False        False  False  False      False
# 18  Works great!.                                                                                                        1                  False      False  True   False       False    False  False        False  False  False      False
# 19  It clicks into place in a way that makes you wonder how long that mechanism would last.                              0                  False      False  False  False       False    False  False        False  False  False      False
# 20  I went on Motorola's website and followed all directions, but could not get it to pair again.                        0                  False      False  False  False       False    False  False        False  False  False      False
# 21  I bought this to use with my Kindle Fire and absolutely loved it!                                                    1                  False      False  False  False       False    True   False        False  False  False      False
# 22  The commercials are the most misleading.                                                                             0                  False      False  False  False       False    False  False        False  False  False      False
# 23  I have yet to run this new battery below two bars and that's three days without charging.                            1                  False      False  False  False       False    False  False        False  False  False      False
# 24  I bought it for my mother and she had a problem with the battery.                                                    0                  False      False  False  False       False    False  False        False  False  False      False
# 25  Great Pocket PC / phone combination.                                                                                 1                  False      False  True   False       False    False  False        False  False  False      False
# 26  I've owned this phone for 7 months now and can say that it's the best mobile phone I've had.                         1                  False      False  False  False       False    False  False        False  True   False      False
# 27  I didn't think that the instructions provided were helpful to me.                                                    0                  False      False  False  False       False    False  False        False  False  False      False
# 28  People couldnt hear me talk and I had to pull out the earphone and talk on the phone.                                0                  False      False  False  False       False    False  False        False  False  False      False
# 29  Doesn't hold charge.                                                                                                 0                  False      False  False  False       False    False  False        False  False  False      False
# 30  This is a simple little phone to use, but the breakage is unacceptible.                                              0                  False      False  False  False       False    False  False        False  False  False      False
# 31  This product is ideal for people like me whose ears are very sensitive.                                              1                  False      False  False  False       False    False  False        False  False  False      False
# 32  It is unusable in a moving car at freeway speed.                                                                     0                  False      False  False  False       False    False  False        False  False  False      False
# 33  I have two more years left in this contract and I hate this phone.                                                   0                  False      False  False  False       False    False  False        False  False  False      False
# 34  Car charger as well as AC charger are included to make sure you never run out of juice.Highy recommended             1                  False      False  False  False       False    False  True         False  False  False      False
# 35  You need at least 3 mins to get to your phone book from the time you first turn on the phone.Battery life is short.  0                  False      False  False  False       False    False  False        False  False  False      False
# 36  It has kept up very well.                                                                                            1                  False      False  False  False       False    False  False        False  False  False      False
# 37  Poor Talk Time Performance.                                                                                          0                  False      False  False  False       False    False  False        False  False  False      False
# 38  The case is great and works fine with the 680.                                                                       1                  False      False  True   False       False    False  False        False  False  False      False
# 39  worthless product.                                                                                                   0                  False      False  False  False       False    False  False        False  False  False      False
# 40  It has a great camera thats 2MP, and the pics are nice and clear with great picture quality.                         1                  False      False  True   False       False    False  False        True   False  False      False
# 41  I was not impressed by this product.                                                                                 0                  False      False  False  False       False    False  False        False  False  False      False
# 42  Nice headset priced right.                                                                                           1                  False      False  False  False       False    False  False        True   False  False      False
# 43  I only hear garbage for audio.                                                                                       0                  False      False  False  False       False    False  False        False  False  False      False
# 44  Excellent bluetooth headset.                                                                                         1                  True       False  False  False       False    False  False        False  False  False      False
# 45  It has all the features I want                                                                                       1                  False      False  False  False       False    False  False        False  False  False      False
# 46  Who in their right mind is gonna buy this battery?.                                                                  0                  False      False  False  False       False    False  False        False  False  False      False
# 47  AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS.                        0                  False      False  False  False       False    False  False        False  False  False      False
# 48  This case seems well made.                                                                                           1                  False      False  False  False       False    False  False        False  False  False      False
# 49  Disappointed with battery.                                                                                           0                  False      False  False  False       False    False  False        False  False  False      False

# %% [markdown]
# So now lets check if the features are independent using seabors's heatmap function.

# %%
sns.heatmap(amazon_data.corr())

# %% [markdown]
# so we can see from the above heatmap that the independence assumption of the naive bayes is met.

# %% [markdown]
# therefore it is time to fit our model.But first lets define our data and target variables and the distribusion of the feature variables in this case is bernouli as we have only two categories in each feature.

# %%
data = amazon_data[keywords]
target = amazon_data['Positive_negative']

# %%
from sklearn.naive_bayes import BernoulliNB

# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()

# Fit our model to the data.
bnb.fit(data, target)

# Classify, storing the result in a new variable.
y_pred = bnb.predict(data)

# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 1000 points : 304

# %% [markdown]
# Finally lets check the above classifier on the other two datasets from yelp and imdb,but first lets load the two data sets.

# %%
imdb_data = pd.read_csv('imdb_labelled.txt', delimiter = '\t', header = None)
yelp_data = pd.read_csv('yelp_labelled.txt', delimiter = '\t', header = None)
imdb_data.columns = ['Reviews', 'Positive_negative']
yelp_data.columns = ['Reviews', 'Positive_negative']

# %%
import re
for key in keywords:
    imdb_data[key] = imdb_data.Reviews.apply(lambda x: bool(re.search(r'{}'.format(key), x, re.IGNORECASE)))
for key in keywords:
    yelp_data[key] = yelp_data.Reviews.apply(lambda x: bool(re.search(r'{}'.format(key), x, re.IGNORECASE)))

# %%
data_imdb = imdb_data[keywords]
target_imdb = imdb_data['Positive_negative']
data_yelp = yelp_data[keywords]
target_yelp = yelp_data['Positive_negative']

# %% [markdown]
# so now lets fit the model and check what happens with the two datasets

# %%
bnb_imdb = BernoulliNB()
bnb_imdb.fit(data_imdb, target_imdb)
y_pred_imdb = bnb_imdb.predict(data_imdb)
print("Number of mislabelled points out of a total {} points in the imdb data is : {}".format(
    data_imdb.shape[0],   
    (target_imdb != y_pred_imdb).sum()
))
print('And the proportion of mislabelled is {}: '.format((target_imdb != y_pred_imdb).sum()/data_imdb.shape[0]))
# Out:
# Number of mislabelled points out of a total 748 points in the imdb data is : 312
# And the proportion of mislabelled is 0.41711229946524064:

# %%
bnb_yelp = BernoulliNB()
bnb_yelp.fit(data_yelp, target_yelp)
y_pred_yelp = bnb_yelp.predict(data_yelp)
print("Number of mislabelled points out of a total {} points in the yelp data is : {}".format(
    data_yelp.shape[0],
    (target_yelp != y_pred_yelp).sum()
))
print('And the proportion of mislabelled is {}: '.format((target_yelp != y_pred_yelp).sum()/data_yelp.shape[0]))
# Out:
# Number of mislabelled points out of a total 1000 points in the yelp data is : 319
# And the proportion of mislabelled is 0.319:
