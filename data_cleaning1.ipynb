# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("purchases.csv")

# %%
df.head()
# Out:
#   Unnamed: 0 country  ad_views  items_purchased
# 0     George      US        16                2
# 1       John     CAN        42                1
# 2     Thomas     CAN        32                0
# 3      James      US        13                8
# 4     Andrew     CAN        63                0

# %%
final = df[lambda df: df['ad_views'] > 17][['country','items_purchased']]

# %%
final.head()
# Out:
#   country  items_purchased
# 1     CAN                1
# 2     CAN                0
# 4     CAN                0
# 5      US                5
# 6      US                7

# %%
final.to_csv('Final.csv')

# %%
dfjson = pd.read_json('purchases.json')

# %%
dfjson.head()
# Out:
#   Unnamed: 0 country  ad_views  items_purchased
# 0     George      US        16                2
# 1       John     CAN        42                1
# 2     Thomas     CAN        32                0
# 3      James      US        13                8
# 4     Andrew     CAN        63                0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3,4]);

# %%
np.random.seed(1221)

# Make a blank data frame.
df = pd.DataFrame()

# Add a column of random numbers between 0 and 1.
df['rand'] = np.random.rand(100)
df['rand_sq'] = df['rand'] ** 2
df['rand_shift'] = df['rand'] + 2

# When creating a data frame an index column of counts is created, counting from 0.
# Here we do a few transforms on that index to create some extra columns.
df['counts_sq'] = df.index ** 2 
df['counts_sqrt'] = np.sqrt(df.index)

# %%
df.columns
# Out:
# Index(['rand', 'rand_sq', 'rand_shift', 'counts_sq', 'counts_sqrt'], dtype='object')

# %%
plt.plot(df['rand']);

# %%
plt.plot(df['rand'],color = 'purple', marker = 'o')
plt.ylim([-0.1, 1.1])
plt.ylabel('Value')
plt.title('Random numbers');

# %%
plt.scatter(x=df['rand'], y=df['rand_sq']);

# %%
df.plot(kind='scatter', x='counts_sq',y= 'counts_sqrt')
df.plot(kind='line')

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(df['rand'], color='purple')
plt.ylabel('Values')
plt.title('Random Series')

plt.subplot(1, 2, 2)
plt.scatter(x = df['rand_sq'], y = df['rand'], color='green')
plt.ylabel('Squared Values')
plt.title('Squared Series');
plt.tight_layout()

# %%
plt.hist(np.random.normal(10, 5, 1000), color = 'blue', bins = np.arange(-10, 40), alpha = 0.5);
plt.hist(np.random.normal(15, 5, 10000), color = 'red', bins = np.arange(-10, 40), alpha = 0.5);

# %%
import pandas as pd

# %%
print('take 5'.isdigit())
# Out:
# False

# %%
print('234'.isdigit())
# Out:
# True

# %%
[1,2,3,4](lambda x: x *2)
# Out:
#   File "<ipython-input-5-256ea81058f2>", line 1
#     [1,2,3,4].(lambda x: x *2)
#               ^
# SyntaxError: invalid syntax
